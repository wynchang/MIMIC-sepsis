# %% [markdown]
# # Sepsis Classifier
#
# The previous sections - Data exploration, preprocessing and Feature Engineering -- have produced a training and a test data set from the MIT MIMIC-III Patient Database for Sepsis Classification. In this section, we will feed the training data to a series of scikit learning classification algorithms to determine if we can recognize sepsis from a patient's vitals and charts.
#
# This notebook will:
# * Upload training and test data.
# * Define and train linear binary classification models.
# * Compute false omission rate and accuracy, recall, precision result measures.
# * Adjust hyperparameters to maximize results.
# * Select the best linear model as benchmark.
# * Define and train non-linear binary classifiers.
# * Measure against the benchmark model.
# * Evaluate the various classifiers and draw conclusions.
#
# ---

# %% [markdown]
# ## Check notebook environment

# %%
from xgboost import XGBClassifier

## if xgboost is not installed, uncomment and run the pip install below. Restart the Kernel.

#!pip install xgboost

# %% [markdown]
# ## Load Data to S3
#
# The sepsis_data directory created contains two files: a `train_bal.csv` and `test.csv` file with the features and sepsis/non-sepsis labels.

# %%
import numpy as np
import pandas as pd
import boto3
import sagemaker
import os

# %%
# session and role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# create an S3 bucket
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Upload the training data to S3
#
# Load the entire directory to S3.

# %%
# should be the name of directory you created to save your features data
data_dir = 'sepsis_data'

# set prefix, a descriptive name for a directory  
prefix = 'sepsis'

# set output path for trainig
output_path = 's3://{}/{}/output'.format(bucket,prefix)

# upload all data to S3
#data_loc = sagemaker_session.upload_data(path=data_dir, bucket=bucket, key_prefix=prefix)
train_loc = sagemaker_session.upload_data(path=os.path.join(data_dir,'train_bal.csv'), bucket=bucket, key_prefix=prefix)
val_loc = sagemaker_session.upload_data(path=os.path.join(data_dir,'validation.csv'), bucket=bucket, key_prefix=prefix)
test_loc = sagemaker_session.upload_data(path=os.path.join(data_dir,'test.csv'), bucket=bucket, key_prefix=prefix)
print(train_loc)
print(val_loc)
print(test_loc)
# Out:
# s3://sagemaker-us-east-1-483763898801/sepsis/train_bal.csv
# s3://sagemaker-us-east-1-483763898801/sepsis/validation.csv
# s3://sagemaker-us-east-1-483763898801/sepsis/test.csv

# %%
s3_train = sagemaker.s3_input(s3_data=train_loc, content_type="text/csv")
s3_val = sagemaker.s3_input(s3_data=val_loc, content_type="text/csv")
s3_test = sagemaker.s3_input(s3_data=test_loc, content_type="text/csv")

#s3_train = sagemaker.s3_input(s3_data=train_loc)
#s3_val = sagemaker.s3_input(s3_data=val_loc)
#s3_test = sagemaker.s3_input(s3_data=test_loc)

# %% [markdown]
# ### Read in data file

# %%
train_file = pd.read_csv(os.path.join(data_dir,'train_bal.csv'), header=None)
test_file = pd.read_csv(os.path.join(data_dir,'test.csv'), header=None)

print(train_file.shape, test_file.shape)
# Out:
# (55760, 13) (14321, 13)

# %%
y_train = train_file.iloc[:,0]
X_train = train_file.iloc[:,1:]

y_test = test_file.iloc[:,0]
X_test = test_file.iloc[:,1:]

print("Train set: ", X_train.shape, y_train.shape)
print("Test set: ", X_test.shape, y_test.shape)
# Out:
# Train set:  (55760, 12) (55760,)
# Test set:  (14321, 12) (14321,)

# %% [markdown]
# ### Train a LinearLearner model as a benchmark model

# %%
# import LinearLearner
from sagemaker import LinearLearner

# instantiate LinearLearner
linear = LinearLearner(role=role,
                      train_instance_count=1,
                      train_instance_type='ml.c4.xlarge',
                      predictor_type='binary_classifier',
                      output_path = 's3://{}/{}/output'.format(bucket,prefix),
                      sagemaker_session=sagemaker_session,
                      epochs=15)

# %% [markdown]
# ### Convert data into RecordSet format before training

# %%
# create RecordSet of training data
train_features_np = X_train.values.astype('float32')
train_labels_np = y_train.values.astype('float32')

formatted_train_data = linear.record_set(train_features_np, labels=train_labels_np)

# %%
# %%time
# train the estimator on formatted training data
linear.fit(formatted_train_data)
# Out:
# 2020-02-08 08:49:47 Starting - Starting the training job...
# 2020-02-08 08:49:49 Starting - Launching requested ML instances.........
# 2020-02-08 08:51:22 Starting - Preparing the instances for training...
# 2020-02-08 08:52:13 Downloading - Downloading input data...
# 2020-02-08 08:52:37 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [02/08/2020 08:52:54 INFO 140349995878208] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/08/2020 08:52:54 INFO 140349995878208] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'15', u'feature_dim': u'12', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier'}
# [02/08/2020 08:52:54 INFO 140349995878208] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'12', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/08/2020 08:52:54 WARNING 140349995878208] Loggers have already been setup.
# Process 1 is a worker.
# [02/08/2020 08:52:54 INFO 140349995878208] Using default worker.
# [2020-02-08 08:52:54.107] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 18, "num_examples": 1, "num_bytes": 92000}
# [02/08/2020 08:52:54 INFO 140349995878208] Create Store: local
# [2020-02-08 08:52:54.150] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 42, "num_examples": 11, "num_bytes": 1012000}
# [02/08/2020 08:52:54 INFO 140349995878208] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa572508150>
# [02/08/2020 08:52:54 INFO 140349995878208] Scaling model computed with parameters:
#  {'stdev_weight':
# [0.49602666 0.24149601 0.20417044 0.16267765 0.20485772 0.16379495
#  0.1258913  0.45922622 0.3838209  0.01836118 0.02454529 0.20497029]
# <NDArray 12 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [0.56290907 0.2037452  0.17329583 0.06849578 0.08786516 0.0688173
#  0.051661   0.39877176 0.33501473 0.00998798 0.01469655 0.6993798 ]
# <NDArray 12 @cpu(0)>}
# [02/08/2020 08:52:54 INFO 140349995878208] nvidia-smi took: 0.0251750946045 secs to identify 0 gpus
# [02/08/2020 08:52:54 INFO 140349995878208] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1581151974.245429, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581151974.245396}
#
# [2020-02-08 08:52:55.707] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 1461, "num_examples": 56, "num_bytes": 5129920}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8349576632412997, "sum": 0.8349576632412997, "min": 0.8349576632412997}}, "EndTime": 1581151975.70756, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.707494}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8347170143821022, "sum": 0.8347170143821022, "min": 0.8347170143821022}}, "EndTime": 1581151975.707643, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.70763}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8332204473322088, "sum": 0.8332204473322088, "min": 0.8332204473322088}}, "EndTime": 1581151975.707679, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.70767}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8310895402388139, "sum": 0.8310895402388139, "min": 0.8310895402388139}}, "EndTime": 1581151975.707711, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.707703}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.33506476153731346, "sum": 0.33506476153731346, "min": 0.33506476153731346}}, "EndTime": 1581151975.707762, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.707746}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3811385651417754, "sum": 0.3811385651417754, "min": 0.3811385651417754}}, "EndTime": 1581151975.707833, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.707813}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3714194466607137, "sum": 0.3714194466607137, "min": 0.3714194466607137}}, "EndTime": 1581151975.707897, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.707879}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3277891493407163, "sum": 0.3277891493407163, "min": 0.3277891493407163}}, "EndTime": 1581151975.707956, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.707939}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8341815007990057, "sum": 0.8341815007990057, "min": 0.8341815007990057}}, "EndTime": 1581151975.708017, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.707999}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.8325682350852273, "sum": 0.8325682350852273, "min": 0.8325682350852273}}, "EndTime": 1581151975.708075, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1581151975.
"Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581151982.442833}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.860391116648912, "sum": 2.860391116648912, "min": 2.860391116648912}}, "EndTime": 1581151982.442903, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581151982.442886}
#
# [02/08/2020 08:53:02 INFO 140349995878208] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy_objective <loss>=0.746722274503
# [02/08/2020 08:53:02 INFO 140349995878208] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=binary_classification_cross_entropy_objective, value=0.746571127042
# [02/08/2020 08:53:02 INFO 140349995878208] Early stop condition met. Stopping training.
# [02/08/2020 08:53:02 INFO 140349995878208] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 56, "sum": 56.0, "min": 56}, "Number of Batches Since Last Reset": {"count": 1, "max": 56, "sum": 56.0, "min": 56}, "Number of Records Since Last Reset": {"count": 1, "max": 55760, "sum": 55760.0, "min": 55760}, "Total Batches Seen": {"count": 1, "max": 292, "sum": 292.0, "min": 292}, "Total Records Seen": {"count": 1, "max": 290800, "sum": 290800.0, "min": 290800}, "Max Records Seen Between Resets": {"count": 1, "max": 55760, "sum": 55760.0, "min": 55760}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1581151982.444971, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581151980.869733}
#
# [02/08/2020 08:53:02 INFO 140349995878208] #throughput_metric: host=algo-1, train throughput=35395.1472374 records/second
# [02/08/2020 08:53:02 WARNING 140349995878208] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/08/2020 08:53:02 WARNING 140349995878208] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-02-08 08:53:02.451] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 5, "num_examples": 1, "num_bytes": 92000}
# [2020-02-08 08:53:02.677] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 223, "num_examples": 56, "num_bytes": 5129920}
# [2020-02-08 08:53:02.854] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 153, "num_examples": 56, "num_bytes": 5129920}
# [02/08/2020 08:53:02 INFO 140349995878208] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 5.637230704656292)
# [02/08/2020 08:53:02 INFO 140349995878208] #train_score (algo-1) : ('binary_classification_accuracy', 0.5166786226685797)
# [02/08/2020 08:53:02 INFO 140349995878208] #train_score (algo-1) : ('binary_f_1.000', 0.6632681110528026)
# [02/08/2020 08:53:02 INFO 140349995878208] #train_score (algo-1) : ('precision', 0.5089159029029413)
# [02/08/2020 08:53:02 INFO 140349995878208] #train_score (algo-1) : ('recall', 0.9520086083213773)
# [02/08/2020 08:53:02 INFO 140349995878208] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=5.63723070466
# [02/08/2020 08:53:02 INFO 140349995878208] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.516678622669
# [02/08/2020 08:53:02 INFO 140349995878208] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.663268111053
# [02/08/2020 08:53:02 INFO 140349995878208] #quality_metric: host=algo-1, train precision <score>=0.508915902903
# [02/08/2020 08:53:02 INFO 140349995878208] #quality_metric: host=algo-1, train recall <score>=0.952008608321
# [02/08/2020 08:53:02 INFO 140349995878208] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [02/08/2020 08:53:02 INFO 140349995878208] Saved checkpoint to "/tmp/tmpmI6D4d/mx-mod-0000.params"
# [02/08/2020 08:53:02 INFO 140349995878208] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 8857.07688331604, "sum": 8857.07688331604, "min": 8857.07688331604}, "finalize.time": {"count": 1, "max": 410.3810787200928, "sum": 410.3810787200928, "min": 410.3810787200928}, "initialize.time": {"count": 1, "max": 152.61411666870117, "sum": 152.61411666870117, "min": 152.61411666870117}, "check_early_stopping.time": {"count": 5, "max": 0.7648468017578125, "sum": 1.5316009521484375, "min": 0.18095970153808594}, "setuptime": {"count": 1, "max": 25.949954986572266, "sum": 25.949954986572266, "min": 25.949954986572266}, "update.time": {"count": 5, "max": 1985.342025756836, "sum": 8196.409225463867, "min": 1466.5451049804688}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1581151982.863436, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581151974.088039}
# 2020-02-08 08:53:14 Uploading - Uploading generated training model
# 2020-02-08 08:53:14 Completed - Training job completed
# Training seconds: 61
# Billable seconds: 61
# CPU times: user 432 ms, sys: 42.1 ms, total: 474 ms
# Wall time: 3min 41s

# %%
# %%time 
# deploy and create a predictor
linear_predictor = linear.deploy(initial_instance_count=1,
                                instance_type='ml.t2.medium')
# Out:
# ---------------------!CPU times: user 314 ms, sys: 33.5 ms, total: 348 ms
# Wall time: 10min 32s

# %% [markdown]
# ## Evaluate the benchmark model
# The aim of our model is to optimize for low false ommission rate (FOR), where <br><b>
# FOR = (false negative)/(false negative + true negative).</b><br>
# <br>
# This is to minimize the chance of sepsis cases going undetected.

# %%
# test one prediction
test_x_np = X_test.values.astype('float32')
result = linear_predictor.predict(test_x_np[0])

print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 1.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.9999866485595703
#     }
#   }
# }
# ]

# %%
def calculate_measures(test_labels, test_preds, verbose=True):
    """
    Calculate the true positive, false positive,
    true negative, false negative, and false omission rate
    """
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
        # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    false_omission_rate = fn / (fn + tn)
    
    # printing a table of metrics
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    false_omission_rate = fn / (fn + tn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print("{:<11} {:.3f}".format('False omission rate:', false_omission_rate))
        print()
        
       
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy, 'FOR':false_omission_rate}

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    false_omission_rate = fn / (fn + tn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print("{:<11} {:.3f}".format('False omission rate:', false_omission_rate))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy, 'FOR':false_omission_rate}

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   X_test.values.astype('float32'), 
                   y_test, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)   0.0    1.0
# actual (row)
# 0.0               1044  12689
# 1.0                 37    551
#
# Recall:     0.937
# Precision:  0.042
# Accuracy:   0.111
# False omission rate: 0.034

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# Deleted linear-learner-2020-02-08-08-49-47-769

# %% [markdown]
# ## Tune benchmark model
# The precision of the first model is too low.
# Tuning the LinearLearner to increase precision

# %%
# instantiate a LinearLearner
# tune the model for a higher precision
linear_precision = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='recall_at_target_precision', # target precision
                              target_precision=0.8) # 80% precision

# %%
# %%time 
# train the estimator on formatted training data
linear_precision.fit(formatted_train_data)
# Out:
# 2020-02-08 09:04:07 Starting - Starting the training job...
# 2020-02-08 09:04:08 Starting - Launching requested ML instances......
# 2020-02-08 09:05:10 Starting - Preparing the instances for training......
# 2020-02-08 09:06:23 Downloading - Downloading input data...
# 2020-02-08 09:07:05 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# [02/08/2020 09:07:08 INFO 140101488289600] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/08/2020 09:07:08 INFO 140101488289600] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'target_precision': u'0.8', u'binary_classifier_model_selection_criteria': u'recall_at_target_precision', u'epochs': u'15', u'feature_dim': u'12', u'mini_batch_size': u'1000'}
# [02/08/2020 09:07:08 INFO 140101488289600] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'12', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'recall_at_target_precision', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/08/2020 09:07:08 WARNING 140101488289600] Loggers have already been setup.
# Process 1 is a worker.
# [02/08/2020 09:07:08 INFO 140101488289600] Using default worker.
# [2020-02-08 09:07:08.529] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 22, "num_examples": 1, "num_bytes": 92000}
# [02/08/2020 09:07:08 INFO 140101488289600] Create Store: local
# [2020-02-08 09:07:08.590] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 60, "num_examples": 11, "num_bytes": 1012000}
# [02/08/2020 09:07:08 INFO 140101488289600] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f6b963ff190>
# [02/08/2020 09:07:08 INFO 140101488289600] Scaling model computed with parameters:
#  {'stdev_weight':
# [0.49602666 0.24149601 0.20417044 0.16267765 0.20485772 0.16379495
#  0.1258913  0.45922622 0.3838209  0.01836118 0.02454529 0.20497029]
# <NDArray 12 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [0.56290907 0.2037452  0.17329583 0.06849578 0.08786516 0.0688173
#  0.051661   0.39877176 0.33501473 0.00998798 0.01469655 0.6993798 ]
# <NDArray 12 @cpu(0)>}
# [02/08/2020 09:07:08 INFO 140101488289600] nvidia-smi took: 0.0252020359039 secs to identify 0 gpus
# [02/08/2020 09:07:08 INFO 140101488289600] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 
}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.3851146351727572, "sum": 2.3851146351727572, "min": 2.3851146351727572}}, "EndTime": 1581152837.133682, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.133665}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.8217695777231997, "sum": 2.8217695777231997, "min": 2.8217695777231997}}, "EndTime": 1581152837.133739, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.133723}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.3865531251864, "sum": 2.3865531251864, "min": 2.3865531251864}}, "EndTime": 1581152837.133794, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.133779}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.8222914514964277, "sum": 2.8222914514964277, "min": 2.8222914514964277}}, "EndTime": 1581152837.133834, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.13382}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7625700816761364, "sum": 0.7625700816761364, "min": 0.7625700816761364}}, "EndTime": 1581152837.133889, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.133873}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7792699795809659, "sum": 0.7792699795809659, "min": 0.7792699795809659}}, "EndTime": 1581152837.133941, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.133926}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7625688321200285, "sum": 0.7625688321200285, "min": 0.7625688321200285}}, "EndTime": 1581152837.134, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.133984}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7792692649147728, "sum": 0.7792692649147728, "min": 0.7792692649147728}}, "EndTime": 1581152837.134043, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.134029}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.424565028541738, "sum": 2.424565028541738, "min": 2.424565028541738}}, "EndTime": 1581152837.134102, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.134086}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.860306386383013, "sum": 2.860306386383013, "min": 2.860306386383013}}, "EndTime": 1581152837.134159, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.134143}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.4243064811403103, "sum": 2.4243064811403103, "min": 2.4243064811403103}}, "EndTime": 1581152837.134212, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.134197}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.860391116648912, "sum": 2.860391116648912, "min": 2.860391116648912}}, "EndTime": 1581152837.134272, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152837.134256}
#
# [02/08/2020 09:07:17 INFO 140101488289600] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy_objective <loss>=0.746722274503
# [02/08/2020 09:07:17 INFO 140101488289600] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=binary_classification_cross_entropy_objective, value=0.746571127042
# [02/08/2020 09:07:17 INFO 140101488289600] Early stop condition met. Stopping training.
# [02/08/2020 09:07:17 INFO 140101488289600] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 56, "sum": 56.0, "min": 56}, "Number of Batches Since Last Reset": {"count": 1, "max": 56, "sum": 56.0, "min": 56}, "Number of Records Since Last Reset": {"count": 1, "max": 55760, "sum": 55760.0, "min": 55760}, "Total Batches Seen": {"count": 1, "max": 292, "sum": 292.0, "min": 292}, "Total Records Seen": {"count": 1, "max": 290800, "sum": 290800.0, "min": 290800}, "Max Records Seen Between Resets": {"count": 1, "max": 55760, "sum": 55760.0, "min": 55760}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1581152837.13641, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581152835.3585}
#
# [02/08/2020 09:07:17 INFO 140101488289600] #throughput_metric: host=algo-1, train throughput=31360.5857978 records/second
# [02/08/2020 09:07:17 WARNING 140101488289600] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/08/2020 09:07:17 WARNING 140101488289600] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-02-08 09:07:17.141] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 4, "num_examples": 1, "num_bytes": 92000}
# [2020-02-08 09:07:17.378] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 234, "num_examples": 56, "num_bytes": 5129920}
# [2020-02-08 09:07:17.593] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 190, "num_examples": 56, "num_bytes": 5129920}
# [02/08/2020 09:07:17 INFO 140101488289600] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 5.637230704656292)
# [02/08/2020 09:07:17 INFO 140101488289600] #train_score (algo-1) : ('binary_classification_accuracy', 0.49879842180774747)
# [02/08/2020 09:07:17 INFO 140101488289600] #train_score (algo-1) : ('binary_f_1.000', 0.6635283352797409)
# [02/08/2020 09:07:17 INFO 140101488289600] #train_score (algo-1) : ('precision', 0.4993928849743562)
# [02/08/2020 09:07:17 INFO 140101488289600] #train_score (algo-1) : ('recall', 0.9883787661406026)
# [02/08/2020 09:07:17 INFO 140101488289600] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=5.63723070466
# [02/08/2020 09:07:17 INFO 140101488289600] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.498798421808
# [02/08/2020 09:07:17 INFO 140101488289600] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.66352833528
# [02/08/2020 09:07:17 INFO 140101488289600] #quality_metric: host=algo-1, train precision <score>=0.499392884974
# [02/08/2020 09:07:17 INFO 140101488289600] #quality_metric: host=algo-1, train recall <score>=0.988378766141
# [02/08/2020 09:07:17 INFO 140101488289600] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [02/08/2020 09:07:17 INFO 140101488289600] Saved checkpoint to "/tmp/tmpmpppVp/mx-mod-0000.params"
# [02/08/2020 09:07:17 INFO 140101488289600] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 9184.006929397583, "sum": 9184.006929397583, "min": 9184.006929397583}, "finalize.time": {"count": 1, "max": 457.46898651123047, "sum": 457.46898651123047, "min": 457.46898651123047}, "initialize.time": {"count": 1, "max": 197.6490020751953, "sum": 197.6490020751953, "min": 197.6490020751953}, "check_early_stopping.time": {"count": 5, "max": 0.84686279296875, "sum": 1.6396045684814453, "min": 0.19097328186035156}, "setuptime": {"count": 1, "max": 26.772022247314453, "sum": 26.772022247314453, "min": 26.772022247314453}, "update.time": {"count": 5, "max": 1829.6170234680176, "sum": 8424.302101135254, "min": 1533.1289768218994}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1581152837.60294, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581152828.506551}
# 2020-02-08 09:07:28 Uploading - Uploading generated training model
# 2020-02-08 09:07:28 Completed - Training job completed
# Training seconds: 65
# Billable seconds: 65
# CPU times: user 453 ms, sys: 9.85 ms, total: 463 ms
# Wall time: 3min 41s

# %%
precision_predictor = linear_precision.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# ---------------------!

# %%
print('Metrics for precision-tuned LinearLearner model.\n')

# get metrics for tuned predictor
metrics = evaluate(precision_predictor, 
                   X_test.values.astype('float32'), 
                   y_test, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for precision-tuned LinearLearner model.
#
# prediction (col)  0.0    1.0
# actual (row)
# 0.0                89  13644
# 1.0                 8    580
#
# Recall:     0.986
# Precision:  0.041
# Accuracy:   0.047
# False omission rate: 0.082

# %%
# delete the predictor endpoint 
delete_endpoint(precision_predictor)
# Out:
# Deleted linear-learner-2020-02-08-09-04-06-893

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.8) # 80% recall

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# 2020-02-08 09:18:25 Starting - Starting the training job...
# 2020-02-08 09:18:27 Starting - Launching requested ML instances......
# 2020-02-08 09:19:31 Starting - Preparing the instances for training......
# 2020-02-08 09:20:56 Downloading - Downloading input data
# 2020-02-08 09:20:56 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [02/08/2020 09:21:11 INFO 140617057535808] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/08/2020 09:21:11 INFO 140617057535808] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'feature_dim': u'12', u'target_recall': u'0.8', u'mini_batch_size': u'1000'}
# [02/08/2020 09:21:11 INFO 140617057535808] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'12', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/08/2020 09:21:11 WARNING 140617057535808] Loggers have already been setup.
# Process 1 is a worker.
# [02/08/2020 09:21:11 INFO 140617057535808] Using default worker.
# [2020-02-08 09:21:11.974] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 17, "num_examples": 1, "num_bytes": 92000}
# [02/08/2020 09:21:11 INFO 140617057535808] Create Store: local
# [2020-02-08 09:21:12.017] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 42, "num_examples": 11, "num_bytes": 1012000}
# [02/08/2020 09:21:12 INFO 140617057535808] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fe3a4cb1150>
# [02/08/2020 09:21:12 INFO 140617057535808] Scaling model computed with parameters:
#  {'stdev_weight':
# [0.49602666 0.24149601 0.20417044 0.16267765 0.20485772 0.16379495
#  0.1258913  0.45922622 0.3838209  0.01836118 0.02454529 0.20497029]
# <NDArray 12 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [0.56290907 0.2037452  0.17329583 0.06849578 0.08786516 0.0688173
#  0.051661   0.39877176 0.33501473 0.00998798 0.01469655 0.6993798 ]
# <NDArray 12 @cpu(0)>}
# [02/08/2020 09:21:12 INFO 140617057535808] nvidia-smi took: 0.0252599716187 secs to identify 0 gpus
# [02/08/2020 09:21:12 INFO 140617057535808] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 
"Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.231585}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7738829356800426, "sum": 0.7738829356800426, "min": 0.7738829356800426}}, "EndTime": 1581153681.231659, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.231643}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.3851146351727572, "sum": 2.3851146351727572, "min": 2.3851146351727572}}, "EndTime": 1581153681.231712, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.2317}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.8217695777231997, "sum": 2.8217695777231997, "min": 2.8217695777231997}}, "EndTime": 1581153681.23176, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.231745}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.3865531251864, "sum": 2.3865531251864, "min": 2.3865531251864}}, "EndTime": 1581153681.23181, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.2318}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.8222914514964277, "sum": 2.8222914514964277, "min": 2.8222914514964277}}, "EndTime": 1581153681.231843, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.231833}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7625700816761364, "sum": 0.7625700816761364, "min": 0.7625700816761364}}, "EndTime": 1581153681.231898, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.231882}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7792699795809659, "sum": 0.7792699795809659, "min": 0.7792699795809659}}, "EndTime": 1581153681.231949, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.231938}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7625688321200285, "sum": 0.7625688321200285, "min": 0.7625688321200285}}, "EndTime": 1581153681.232001, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.231985}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7792692649147728, "sum": 0.7792692649147728, "min": 0.7792692649147728}}, "EndTime": 1581153681.232055, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.232044}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.424565028541738, "sum": 2.424565028541738, "min": 2.424565028541738}}, "EndTime": 1581153681.232104, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.232092}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.860306386383013, "sum": 2.860306386383013, "min": 2.860306386383013}}, "EndTime": 1581153681.232169, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.232151}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.4243064811403103, "sum": 2.4243064811403103, "min": 2.4243064811403103}}, "EndTime": 1581153681.232235, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.232218}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 2.860391116648912, "sum": 2.860391116648912, "min": 2.860391116648912}}, "EndTime": 1581153681.232294, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153681.232278}
#
# [02/08/2020 09:21:21 INFO 140617057535808] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy_objective <loss>=0.746722274503
# [02/08/2020 09:21:21 INFO 140617057535808] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=binary_classification_cross_entropy_objective, value=0.746571127042
# [02/08/2020 09:21:21 INFO 140617057535808] Early stop condition met. Stopping training.
# [02/08/2020 09:21:21 INFO 140617057535808] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 56, "sum": 56.0, "min": 56}, "Number of Batches Since Last Reset": {"count": 1, "max": 56, "sum": 56.0, "min": 56}, "Number of Records Since Last Reset": {"count": 1, "max": 55760, "sum": 55760.0, "min": 55760}, "Total Batches Seen": {"count": 1, "max": 292, "sum": 292.0, "min": 292}, "Total Records Seen": {"count": 1, "max": 290800, "sum": 290800.0, "min": 290800}, "Max Records Seen Between Resets": {"count": 1, "max": 55760, "sum": 55760.0, "min": 55760}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1581153681.234436, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 4}, "StartTime": 1581153679.441679}
#
# [02/08/2020 09:21:21 INFO 140617057535808] #throughput_metric: host=algo-1, train throughput=31100.992088 records/second
# [02/08/2020 09:21:21 WARNING 140617057535808] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/08/2020 09:21:21 WARNING 140617057535808] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-02-08 09:21:21.239] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 4, "num_examples": 1, "num_bytes": 92000}
# [2020-02-08 09:21:21.482] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 240, "num_examples": 56, "num_bytes": 5129920}
# [2020-02-08 09:21:21.696] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 191, "num_examples": 56, "num_bytes": 5129920}
# [02/08/2020 09:21:21 INFO 140617057535808] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 5.637230704656292)
# [02/08/2020 09:21:21 INFO 140617057535808] #train_score (algo-1) : ('binary_classification_accuracy', 0.5166786226685797)
# [02/08/2020 09:21:21 INFO 140617057535808] #train_score (algo-1) : ('binary_f_1.000', 0.6632681110528026)
# [02/08/2020 09:21:21 INFO 140617057535808] #train_score (algo-1) : ('precision', 0.5089159029029413)
# [02/08/2020 09:21:21 INFO 140617057535808] #train_score (algo-1) : ('recall', 0.9520086083213773)
# [02/08/2020 09:21:21 INFO 140617057535808] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=5.63723070466
# [02/08/2020 09:21:21 INFO 140617057535808] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.516678622669
# [02/08/2020 09:21:21 INFO 140617057535808] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.663268111053
# [02/08/2020 09:21:21 INFO 140617057535808] #quality_metric: host=algo-1, train precision <score>=0.508915902903
# [02/08/2020 09:21:21 INFO 140617057535808] #quality_metric: host=algo-1, train recall <score>=0.952008608321
# [02/08/2020 09:21:21 INFO 140617057535808] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [02/08/2020 09:21:21 INFO 140617057535808] Saved checkpoint to "/tmp/tmpwhAC1U/mx-mod-0000.params"
# [02/08/2020 09:21:21 INFO 140617057535808] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 9832.258939743042, "sum": 9832.258939743042, "min": 9832.258939743042}, "finalize.time": {"count": 1, "max": 463.38796615600586, "sum": 463.38796615600586, "min": 463.38796615600586}, "initialize.time": {"count": 1, "max": 156.8288803100586, "sum": 156.8288803100586, "min": 156.8288803100586}, "check_early_stopping.time": {"count": 5, "max": 0.7979869842529297, "sum": 1.6531944274902344, "min": 0.18715858459472656}, "setuptime": {"count": 1, "max": 25.048017501831055, "sum": 25.048017501831055, "min": 25.048017501831055}, "update.time": {"count": 5, "max": 2006.1559677124023, "sum": 9114.763975143433, "min": 1670.2089309692383}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1581153681.705559, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581153671.955756}
# 2020-02-08 09:21:31 Completed - Training job completed
# Training seconds: 41
# Billable seconds: 41
# CPU times: user 454 ms, sys: 20.3 ms, total: 474 ms
# Wall time: 3min 42s

# %%
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# -----------------------!

# %%
print('Metrics for tuned LinearLearner - target 80% recall.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   X_test.values.astype('float32'), 
                   y_test, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for tuned LinearLearner - target 80% recall.
#
# prediction (col)   0.0    1.0
# actual (row)
# 0.0               1044  12689
# 1.0                 37    551
#
# Recall:     0.937
# Precision:  0.042
# Accuracy:   0.111
# False omission rate: 0.034

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# Deleted linear-learner-2020-02-08-09-18-25-799

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC

# Instantiate
svc = SVC(kernel="linear", C=0.025)

# %%
# %%time
svc.fit(X_train, y_train)
# Out:
# CPU times: user 1min 16s, sys: 103 ms, total: 1min 16s
# Wall time: 1min 16s
# SVC(C=0.025, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
svc_y_pred = svc.predict(X_test)

# %%
print("Metrics for Support Vector Classifier:\n")
calculate_measures(y_test, svc_y_pred)
# Out:
# Metrics for Support Vector Classifier:
#
# prediction (col)   0.0   1.0
# actual (row)
# 0.0               6343  7390
# 1.0                213   375
#
# Recall:     0.638
# Precision:  0.048
# Accuracy:   0.469
# False omission rate: 0.032
# {'TP': 375,
#  'FP': 7390,
#  'FN': 213,
#  'TN': 6343,
#  'Precision': 0.04829362524146812,
#  'Recall': 0.6377551020408163,
#  'Accuracy': 0.4691013197402416,
#  'FOR': 0.03248932275777913}

# %% [markdown]
# ### Linear model conclusions
# After running the default LinearLearner model, and tuned versions of target precision and target recall, it is observed that the Support Vector Classifier is the best linear model. It is able to detect 375 out of 588 sepsis cases in the test dataset. It has the lowest false admission rate and an accuracy of 46.9%.

# %% [markdown]
# ## Train with non-linear binary classifiers
# Now we train the dataset with non-linear binary classifiers to see if there are better results.

# %% [markdown]
# ### K-Neighbor Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

## Instantiate a K-Neighbor classifier
knn = KNeighborsClassifier(weights='distance',leaf_size=500,n_neighbors=2)

# %%
# %%time
knn.fit(X_train, y_train)
# Out:
# CPU times: user 1.8 s, sys: 36 µs, total: 1.8 s
# Wall time: 1.79 s
# KNeighborsClassifier(algorithm='auto', leaf_size=500, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#            weights='distance')

# %%
knn_y_pred = knn.predict(X_test)

# %%
print("Metrics for KNeighborsClassifier:\n")
calculate_measures(y_test, knn_y_pred)
# Out:
# Metrics for KNeighborsClassifier:
#
# prediction (col)    0.0  1.0
# actual (row)
# 0.0               12936  797
# 1.0                 534   54
#
# Recall:     0.092
# Precision:  0.063
# Accuracy:   0.907
# False omission rate: 0.040
# {'TP': 54,
#  'FP': 797,
#  'FN': 534,
#  'TN': 12936,
#  'Precision': 0.06345475910693302,
#  'Recall': 0.09183673469387756,
#  'Accuracy': 0.9070595628796871,
#  'FOR': 0.03964365256124722}

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1)

# %%
# make predictions for test data
xgb_y_pred = xgb.predict(X_test)
predictions = [round(value) for value in xgb_y_pred]

# %%
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 51.18%

# %%
print("Metrics for XGBClassifier:\n")
calculate_measures(y_test, xgb_y_pred)
# Out:
# Metrics for XGBClassifier:
#
# prediction (col)   0.0   1.0
# actual (row)
# 0.0               6948  6785
# 1.0                206   382
#
# Recall:     0.650
# Precision:  0.053
# Accuracy:   0.512
# False omission rate: 0.029
# {'TP': 382,
#  'FP': 6785,
#  'FN': 206,
#  'TN': 6948,
#  'Precision': 0.05329984651876657,
#  'Recall': 0.6496598639455783,
#  'Accuracy': 0.5118357656588227,
#  'FOR': 0.0287950796757059}

# %% [markdown]
# ### Radial Basic Function Support Vector Classifier (RBF SVC)
# Instantiate a K-Neighbor classifier

# %%
from sklearn.svm import SVC
rbfsvc = SVC(gamma=2, C=1)
rbfsvc.fit(X_train, y_train)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=2, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# make predictions for test data
rbf_y_pred = rbfsvc.predict(X_test)

# %%
print("Metrics for RBF SVC:\n")
calculate_measures(y_test, rbf_y_pred)
# Out:
# Metrics for RBF SVC:
#
# prediction (col)   0.0   1.0
# actual (row)
# 0.0               6763  6970
# 1.0                201   387
#
# Recall:     0.658
# Precision:  0.053
# Accuracy:   0.499
# False omission rate: 0.029
# {'TP': 387,
#  'FP': 6970,
#  'FN': 201,
#  'TN': 6763,
#  'Precision': 0.052602963164333286,
#  'Recall': 0.6581632653061225,
#  'Accuracy': 0.4992668109768871,
#  'FOR': 0.028862722573233773}

# %% [markdown]
# ## Non-linear model conclusions
# Of the 3 non-linear models built, the XGBoost Classifier and Radial Basic Function Support Vector Classifier beat the KNeighborClassifier, as well as the benchmark linear model. Between the XGBoost Classifier and Radial Basic Function Support Vector Classifier, XGBoost Classifier has a higher accuracy of 58.4%, and has correctly identified more than half of both the sepsis and non-sepsis cases.

# %% [markdown]
# ---
# ## Conclusions
#
# For future iterations to this project, these are features to improve on:
# * Further adjust hyperparameters to improve model performance.
# * Revisit the dataset and find more features to improve the model training.
